# %%
import numpy as np
import pandas as pd

# %%
root = '/Users/kojin/Dropbox/DeepLP Final Data'

# %%
root = '/Users/kojin/Dropbox/DeepLP Final Data'
last = pd.read_csv(f'{root}/edge/last_cora_citeseer.txt',delimiter=' ',header=None)
average_acc = pd.read_csv(f'{root}/edge/average_acc_cora_citeseer.txt',delimiter=' ',header=None)

# %%
idx = average_acc.groupby([1,2])[4].transform(max) == average_acc[4]

# %%
max_average_acc = average_acc[idx]

# %%
def rem_col(el):
    val,_,_ = el.partition(':')
    return val

# %%
def concat_vals(row):
    return f'{row[1]}{row[2]}{row[3]}'

# %%
max_average_acc['id']=max_average_acc.apply(concat_vals,axis=1)
# Out:
# /Users/kojin/anaconda/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
last['id']=last.apply(concat_vals,axis=1)

# %%
last[last['id'].isin(list(max_average_acc['id']))].groupby(1)[7].mean()
# Out:
# 1
# citeseer    0.557998
# cora        0.666556
# Name: 7, dtype: float64

# %%
last[last['id'].isin(list(max_average_acc['id']))]
# Out:
#                             0         1  2     3         4         5  \
# 5    val2.43566780.txt:++last      cora  0  -8.0  0.122425  0.132670
# 14   val2.43566789.txt:++last      cora  1 -10.0  0.094642  0.123799
# 20   val2.43566795.txt:++last      cora  2 -30.0  0.139769  0.139769
# 35   val2.43566810.txt:++last      cora  3  -8.0  0.194120  0.208409
# 44   val2.43566819.txt:++last      cora  4 -10.0  0.123455  0.139427
# 55   val2.43566830.txt:++last      cora  5  -8.0  0.239495  0.252186
# 65   val2.43566841.txt:++last      cora  6  -8.0  0.226474  0.232361
# 72   val2.43566848.txt:++last      cora  7 -14.0  0.075563  0.078156
# 73   val2.43566849.txt:++last      cora  7 -12.0  0.075985  0.085013
# 84   val2.43566860.txt:++last      cora  8 -10.0  0.089584  0.103623
# 92   val2.43566870.txt:++last      cora  9 -14.0  0.050113  0.055828
# 106  val2.43566886.txt:++last  citeseer  0  -6.0  0.283443  0.286097
# 110  val2.43566890.txt:++last  citeseer  1 -30.0  0.191425  0.191426
# 129  val2.43566909.txt:++last  citeseer  2   4.0  0.313103  0.313104
# 139  val2.43566919.txt:++last  citeseer  3   4.0  0.274407  0.274417
# 146  val2.43566926.txt:++last  citeseer  4  -6.0  0.236825  0.244332
# 159  val2.43566939.txt:++last  citeseer  5   4.0  0.203828  0.203829
# 166  val2.43566946.txt:++last  citeseer  6  -6.0  0.246859  0.249445
# 174  val2.43566954.txt:++last  citeseer  7 -10.0  0.262651  0.274431
# 183  val2.43566963.txt:++last  citeseer  8 -12.0  0.188901  0.197196
# 199  val2.43566979.txt:++last  citeseer  9   4.0  0.377332  0.377346
#
#             6         7         8         9        10            11  \
# 5    0.129252  0.705285  0.797774  0.000000  0.000000  2.622760e+00
# 14   0.206900  0.684959  0.488490  0.000000  0.000000  2.985593e+01
# 20   0.168355  0.728862  0.576017  0.000000  0.000000  1.260299e+02
# 35   0.176153  0.638211  0.911364  0.000000  0.000000  3.657826e+00
# 44   0.207320  0.732114  0.231693  0.000000  0.000000  1.635575e+01
# 55   0.196947  0.589431  1.401020  0.000000  0.000000  3.248882e+00
# 65   0.173341  0.602033  1.354230  0.000000  0.000000  1.507098e+00
# 72   0.262733  0.682927  0.200013  0.142857  0.076923  4.248052e+01
# 73   0.263340  0.683740  0.201138  0.000000  0.000000  3.697749e+01
# 84   0.266306  0.656098  0.274066  0.142857  0.076923  1.437607e+01
# 92   0.312557  0.628455  0.338921  0.000000  0.000000  9.362897e+01
# 106  0.216155  0.591954  1.180780  0.000000  0.000000  1.698214e-01
# 110  0.291202  0.584291  0.621211  0.000000  0.000000  1.823638e+02
# 129  0.257894  0.481801  1.557940  0.000000  0.000000  7.844675e-08
# 139  0.194145  0.545977  1.253370  0.000000  0.000000  6.582619e-07
# 146  0.206389  0.605843  1.139710  0.000000  0.000000  4.804732e-01
# 159  0.215963  0.655651  1.002680  0.000000  0.000000  5.760839e-08
# 166  0.211023  0.611590  1.216430  0.000000  0.000000  1.654828e-01
# 174  0.262532  0.564176  1.334450  0.000000  0.000000  1.206278e+01
# 183  0.240012  0.538314  0.930487  0.000000  0.000000  3.397332e+01
# 199  0.200330  0.400383  1.442780  0.000000  0.000000  8.572221e-07
#
#                  id
# 5         cora0-8.0
# 14       cora1-10.0
# 20       cora2-30.0
# 35        cora3-8.0
# 44       cora4-10.0
# 55        cora5-8.0
# 65        cora6-8.0
# 72       cora7-14.0
# 73       cora7-12.0
# 84       cora8-10.0
# 92       cora9-14.0
# 106   citeseer0-6.0
# 110  citeseer1-30.0
# 129    citeseer24.0
# 139    citeseer34.0
# 146   citeseer4-6.0
# 159    citeseer54.0
# 166   citeseer6-6.0
# 174  citeseer7-10.0
# 183  citeseer8-12.0
# 199    citeseer94.0

# %%
list(max_average_acc['id'])
# Out:
# ['cora0-8.0',
#  'cora1-10.0',
#  'cora2-30.0',
#  'cora3-8.0',
#  'cora4-12.0',
#  'cora5-8.0',
#  'cora6-8.0',
#  'cora7-30.0',
#  'cora8-12.0',
#  'cora9-12.0',
#  'citeseer0-6.0',
#  'citeseer1-4.0',
#  'citeseer24.0',
#  'citeseer34.0',
#  'citeseer4-7.0',
#  'citeseer54.0',
#  'citeseer6-6.0',
#  'citeseer7-8.0',
#  'citeseer8-8.0',
#  'citeseer94.0']

# %%
last['id']
# Out:
# 0          cora0-30
# 1          cora0-14
# 2          cora0-12
# 3          cora0-10
# 4           cora0-9
# 5           cora0-8
# 6           cora0-7
# 7           cora0-6
# 8           cora0-4
# 9            cora04
# 10         cora1-30
# 11         cora1-14
# 12         cora1-12
# 13         cora1-10
# 14          cora1-9
# 15          cora1-8
# 16          cora1-7
# 17          cora1-6
# 18          cora1-4
# 19           cora14
# 20         cora2-30
# 21         cora2-14
# 22         cora2-12
# 23         cora2-10
# 24          cora2-9
# 25          cora2-8
# 26          cora2-7
# 27          cora2-6
# 28          cora2-4
# 29           cora24
#            ...
# 170    citeseer7-30
# 171    citeseer7-14
# 172    citeseer7-12
# 173    citeseer7-10
# 174     citeseer7-9
# 175     citeseer7-8
# 176     citeseer7-7
# 177     citeseer7-6
# 178     citeseer7-4
# 179      citeseer74
# 180    citeseer8-30
# 181    citeseer8-14
# 182    citeseer8-12
# 183    citeseer8-10
# 184     citeseer8-9
# 185     citeseer8-8
# 186     citeseer8-7
# 187     citeseer8-6
# 188     citeseer8-4
# 189      citeseer84
# 190    citeseer9-30
# 191    citeseer9-14
# 192    citeseer9-12
# 193    citeseer9-10
# 194     citeseer9-9
# 195     citeseer9-8
# 196     citeseer9-7
# 197     citeseer9-6
# 198     citeseer9-4
# 199      citeseer94
# Name: id, Length: 200, dtype: object

# %%
logreg = LogisticRegression(multi_class='multinomial',solver='lbfgs',class_weight='balanced')
logreg.fit(features[labeled_indices], np.argmax(labels[labeled_indices],axis=1))
y_pred = logreg.predict_proba(features[unlabeled_indices])
