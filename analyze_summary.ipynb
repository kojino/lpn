# %%
lines = tuple(open('summary_2/grep.txt', 'r'))

# %%
import os
fs = os.listdir("summary_bif")

# %%
fss = []
for f in fs:
    if f[-5]=='5':
        fss.append(f)

# %%
res
# Out:
# [0.0, -10.0, 9.0, 80.0, 0.16]

# %%
ress = []
for f in fss:
    fp = open(f'summary_bif/{f}')
    acc = 0
    for i, line in enumerate(fp):
        if i in [200,400,600,800,1000]:
            acc += float(line.split(',')[-1].strip('\n'))
    acc = acc / 5.0
    fp.close()
    res = f.split('_')[2:-1]
    res = [float(el) for el in res]
    res.append(acc)
    if res[0] == 0.01:
        ress.append(res)
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-13-58bbd3b8b9d8> in <module>()
#       1 ress = []
# ----> 2 for f in fss:
#       3     fp = open(f'summary_bif/{f}')
#       4     acc = 0
#       5     for i, line in enumerate(fp):
#
# NameError: name 'fss' is not defined

# %%
# cols = ['lamda','split','t','acc','valacc','loss','a','b','obj']
cols = ['bif','lamda','split','t','acc','loss','a','b','obj']
# cols = ['bif','lamda','split','t','valacc']

# %%
ress = []
for i in range(int(len(lines)/3)):
    a = lines[3*i].split('_')[2:-1]
    b = lines[3*i+1].split(',')
    res = a+b
    res = [float(el) for el in res]
    ress.append(res)

# %%
import pandas as pd
df = pd.DataFrame(ress, columns=cols)
dfbif = df[df.bif==0.01]
dfnonbif = df[df.bif==0.0]
# dfbif = dfbif.sort_values(by=['split','t'])

# %%
df.shape
# Out:
# (899, 9)

# %%
df.loc[df.groupby(['split','t'])['acc'].idxmax()]['acc']
# Out:
# 251    11.726422
# 51     12.840244
# 151    12.967073
# 261    13.047561
# 751    13.025610
# 351    13.054878
# 211    13.061382
# 451    13.182927
# 671    13.289838
# 651    13.404878
# 241    13.320325
# 281    13.440650
# 551    13.482520
# 141    13.588211
# 271    13.578862
# 171    13.771544
# 161    13.934146
# 41     13.950406
# 181    14.059350
# 71     13.952846
# 871    14.259756
# 771    14.277642
# 371    14.347967
# 81     14.430081
# 201    14.563821
# 471    14.435772
# 571    14.523578
# 681    14.600813
# 641    14.746748
# 61     14.764634
#          ...
# 290    16.280895
# 30     16.275204
# 90     16.388618
# 280    16.409349
# 320    16.071138
# 510    16.365448
# 80     16.555285
# 110    16.617073
# 610    16.642683
# 420    16.516666
# 580    16.630081
# 440    16.576424
# 170    16.809349
# 500    17.075203
# 680    16.881708
# 540    16.954065
# 70     16.986586
# 10     17.105284
# 240    17.260162
# 220    17.208942
# 100    17.359756
# 0      17.399593
# 140    17.466261
# 600    17.556503
# 520    17.641870
# 200    17.892277
# 20     17.912601
# 40     18.014227
# 620    18.066668
# 640    18.152845
# Name: acc, Length: 810, dtype: float64

# %%
# %%bash
#     a=!wc -l summary_deeplp_0.01_0.0_$i_100_1.csv
#     print(a)
# Out:
# UsageError: Line magic function `%wc` not found.

# %%
dfbif.groupby(['split','t'])['acc'].max().to_csv('res.csv')

# %%
# dfbif.loc[dfbif.groupby(['split','t'])['valacc'].idxmax()].to_csv('t_deeplp_val.csv')

# %%
dfbif.loc[dfbif.groupby(['split','t'])['acc'].idxmax()].to_csv('bif_cora_edge.csv')

# %%
dfnonbif.loc[dfnonbif.groupby(['split','t'])['acc'].idxmax()].to_csv('nobif_cora_edge.csv')

# %%
dfbif.loc[dfbif.groupby(['split','t'])['acc'].idxmax()].groupby('split')['acc'].mean()
# Out:
# 0.65137400000000001

# %%
d=dfbif[dfbif.t==20.0]
d[d.t==20.0].loc[d.groupby(['split'])['acc'].idxmax()].groupby('split')['acc'].mean().mean()
# Out:
#       bif  lamda  split     t       acc      loss         a         b  \
# 402  0.01   -4.0    0.0  20.0  0.693496  0.160248  0.017871  0.025141
# 412  0.01   -4.0    1.0  20.0  0.654878  0.177726  0.019684  0.014001
# 422  0.01   -4.0    2.0  20.0  0.696341  0.161833  0.019051  0.043006
# 532  0.01   -6.0    3.0  20.0  0.658130  0.185832  0.017038  0.015989
# 542  0.01   -6.0    4.0  20.0  0.706504  0.160376  0.014233  0.055055
# 152  0.01  -12.0    5.0  20.0  0.583333  0.236885  0.018092  0.011906
# 362  0.01   -2.0    6.0  20.0  0.691463  0.182738  0.013200  0.023665
# 572  0.01   -6.0    7.0  20.0  0.588618  0.175395  0.015079  0.024879
# 882  0.01    2.0    8.0  20.0  0.666667  0.192387  0.025196  0.029236
# 592  0.01   -6.0    9.0  20.0  0.708537  0.173140  0.019075  0.015628
#
#           obj
# 402  0.152950
# 412  0.165214
# 422  0.188335
# 532  0.195949
# 542  0.242524
# 152  0.198041
# 362  0.231991
# 572  0.194388
# 882  0.135809
# 592  0.141478

# %%
d=dfnonbif[dfnonbif.t==20.0]
d[d.t==20.0].loc[d.groupby(['split'])['acc'].idxmax()].groupby('split')['acc'].mean().mean()
# Out:
# 0.6553253

# %%
dfbif.loc[dfbif.groupby(['split','t'])['acc'].idxmax()].groupby('t')['acc'].mean()
# Out:
# t
# 10.0     0.643496
# 20.0     0.664797
# 30.0     0.671463
# 40.0     0.673496
# 50.0     0.674106
# 60.0     0.673537
# 70.0     0.667886
# 80.0     0.641098
# 90.0     0.617724
# 100.0    0.586138
# Name: acc, dtype: float64

# %%
dfnonbif.loc[dfnonbif.groupby(['split','t'])['acc'].idxmax()].groupby('t')['acc'].mean()
# Out:
# t
# 10.0     0.636504
# 20.0     0.655325
# 30.0     0.662683
# 40.0     0.664471
# 50.0     0.658984
# 60.0     0.652927
# 70.0     0.648252
# 80.0     0.646626
# 90.0     0.642236
# 100.0    0.636260
# Name: acc, dtype: float64

# %%
dfnonbif.loc[dfnonbif.groupby(['split','t'])['acc'].idxmax()].groupby('split')['acc'].mean()
# Out:
#       bif  lamda  split      t       acc      loss    a    b       obj
# 901   0.0  -10.0    0.0   10.0  0.693089  0.285177  0.0  0.0  0.292477
# 902   0.0  -10.0    0.0   20.0  0.704472  0.263318  0.0  0.0  0.270284
# 1503  0.0   -8.0    0.0   30.0  0.711789  0.254424  0.0  0.0  0.262304
# 1504  0.0   -8.0    0.0   40.0  0.717073  0.244562  0.0  0.0  0.252883
# 1505  0.0   -8.0    0.0   50.0  0.720325  0.236729  0.0  0.0  0.245632
# 1506  0.0   -8.0    0.0   60.0  0.717886  0.230299  0.0  0.0  0.239820
# 1507  0.0   -8.0    0.0   70.0  0.716667  0.224898  0.0  0.0  0.235035
# 1508  0.0   -8.0    0.0   80.0  0.716260  0.220285  0.0  0.0  0.231019
# 1509  0.0   -8.0    0.0   90.0  0.714634  0.216291  0.0  0.0  0.227602
# 1500  0.0   -8.0    0.0  100.0  0.711382  0.212797  0.0  0.0  0.224663
# 1311  0.0   -4.0    1.0   10.0  0.626423  0.310054  0.0  0.0  0.316710
# 1412  0.0   -6.0    1.0   20.0  0.641463  0.294130  0.0  0.0  0.301078
# 1413  0.0   -6.0    1.0   30.0  0.648374  0.283428  0.0  0.0  0.291768
# 1414  0.0   -6.0    1.0   40.0  0.645528  0.275520  0.0  0.0  0.285401
# 1515  0.0   -8.0    1.0   50.0  0.645122  0.266084  0.0  0.0  0.278567
# 1516  0.0   -8.0    1.0   60.0  0.647561  0.260384  0.0  0.0  0.274839
# 1517  0.0   -8.0    1.0   70.0  0.652032  0.255526  0.0  0.0  0.271857
# 1518  0.0   -8.0    1.0   80.0  0.654472  0.251288  0.0  0.0  0.269400
# 1519  0.0   -8.0    1.0   90.0  0.655285  0.247520  0.0  0.0  0.267326
# 1510  0.0   -8.0    1.0  100.0  0.654878  0.244119  0.0  0.0  0.265540
# 1721  0.0    2.0    2.0   10.0  0.647154  0.294900  0.0  0.0  0.288630
# 1422  0.0   -6.0    2.0   20.0  0.676016  0.283439  0.0  0.0  0.281448
# 1223  0.0   -2.0    2.0   30.0  0.689837  0.275708  0.0  0.0  0.277821
# 1524  0.0   -8.0    2.0   40.0  0.700406  0.267970  0.0  0.0  0.271424
# 1525  0.0   -8.0    2.0   50.0  0.704472  0.262312  0.0  0.0  0.269035
# 1526  0.0   -8.0    2.0   60.0  0.706504  0.257402  0.0  0.0  0.267166
# 1527  0.0   -8.0    2.0   70.0  0.706098  0.253023  0.0  0.0  0.265647
# 1528  0.0   -8.0    2.0   80.0  0.708943  0.249046  0.0  0.0  0.264374
# 1529  0.0   -8.0    2.0   90.0  0.711789  0.245386  0.0  0.0  0.263279
# 1520  0.0   -8.0    2.0  100.0  0.713415  0.241985  0.0  0.0  0.262316
# ...   ...    ...    ...    ...       ...       ...  ...  ...       ...
# 971   0.0  -10.0    7.0   10.0  0.596748  0.263628  0.0  0.0  0.282607
# 972   0.0  -10.0    7.0   20.0  0.607724  0.252389  0.0  0.0  0.274436
# 973   0.0  -10.0    7.0   30.0  0.630894  0.243798  0.0  0.0  0.267822
# 1174  0.0  -14.0    7.0   40.0  0.652846  0.237052  0.0  0.0  0.257508
# 975   0.0  -10.0    7.0   50.0  0.630081  0.231633  0.0  0.0  0.257586
# 976   0.0  -10.0    7.0   60.0  0.619919  0.227263  0.0  0.0  0.253641
# 977   0.0  -10.0    7.0   70.0  0.612195  0.223678  0.0  0.0  0.250287
# 978   0.0  -10.0    7.0   80.0  0.610569  0.220682  0.0  0.0  0.247410
# 979   0.0  -10.0    7.0   90.0  0.604065  0.218132  0.0  0.0  0.244918
# 970   0.0  -10.0    7.0  100.0  0.598374  0.215925  0.0  0.0  0.242741
# 1281  0.0   -2.0    8.0   10.0  0.618293  0.327199  0.0  0.0  0.337624
# 1782  0.0    2.0    8.0   20.0  0.645122  0.314998  0.0  0.0  0.326824
# 1283  0.0   -2.0    8.0   30.0  0.650406  0.306536  0.0  0.0  0.319180
# 1784  0.0    2.0    8.0   40.0  0.652439  0.300422  0.0  0.0  0.313812
# 1285  0.0   -2.0    8.0   50.0  0.652032  0.295480  0.0  0.0  0.309545
# 1686  0.0    0.0    8.0   60.0  0.650813  0.291674  0.0  0.0  0.306411
# 1687  0.0    0.0    8.0   70.0  0.648374  0.288430  0.0  0.0  0.303791
# 1288  0.0   -2.0    8.0   80.0  0.642276  0.285542  0.0  0.0  0.301498
# 1689  0.0    0.0    8.0   90.0  0.634959  0.283280  0.0  0.0  0.299800
# 1680  0.0    0.0    8.0  100.0  0.625203  0.281178  0.0  0.0  0.298243
# 1491  0.0   -6.0    9.0   10.0  0.671138  0.343264  0.0  0.0  0.415836
# 1492  0.0   -6.0    9.0   20.0  0.687805  0.317577  0.0  0.0  0.381073
# 1393  0.0   -4.0    9.0   30.0  0.683333  0.302938  0.0  0.0  0.362432
# 1494  0.0   -6.0    9.0   40.0  0.671545  0.289749  0.0  0.0  0.347630
# 1495  0.0   -6.0    9.0   50.0  0.651219  0.280966  0.0  0.0  0.337787
# 1596  0.0   -8.0    9.0   60.0  0.626829  0.266967  0.0  0.0  0.323367
# 1497  0.0   -6.0    9.0   70.0  0.601220  0.268309  0.0  0.0  0.323878
# 1598  0.0   -8.0    9.0   80.0  0.583333  0.254310  0.0  0.0  0.308589
# 1599  0.0   -8.0    9.0   90.0  0.572764  0.249272  0.0  0.0  0.302443
# 1590  0.0   -8.0    9.0  100.0  0.560976  0.244877  0.0  0.0  0.297042
#
# [100 rows x 9 columns]

# %%
df.shape,dfbif.shape
# Out:
# ((899, 9), (797, 9))

# %%
d = dfbif.loc[dfbif.groupby(['split','t'])['acc'].idxmax()]

# %%
d = d[d.t==20]

# %%
dfbif.loc[dfbif.groupby(['split','t'])['valacc'].idxmax()]
# Out:
#       bif  lamda  split      t  valacc
# 161  0.01  -12.0    0.0   10.0    0.52
# 420  0.01  -14.0    0.0   20.0    0.52
# 329  0.01  -10.0    0.0   30.0    0.68
# 42   0.01   -8.0    0.0   40.0    0.64
# 442  0.01  -10.0    0.0   50.0    0.40
# 378  0.01  -14.0    0.0   60.0    0.16
# 515  0.01   -4.0    0.0   70.0    0.16
# 44   0.01   -8.0    0.0   80.0    0.00
# 134  0.01   -6.0    0.0   90.0    0.00
# 16   0.01    0.0    0.0  100.0    0.00
# 95   0.01    2.0    1.0   10.0    0.64
# 59   0.01   -4.0    1.0   20.0    0.64
# 68   0.01    2.0    1.0   30.0    0.36
# 43   0.01   -8.0    1.0   40.0    0.48
# 439  0.01  -10.0    1.0   50.0    0.48
# 213  0.01  -10.0    1.0   60.0    0.24
# 61   0.01  -12.0    1.0   70.0    0.12
# 145  0.01    0.0    1.0   80.0    0.00
# 135  0.01   -6.0    1.0   90.0    0.00
# 49   0.01   -2.0    1.0  100.0    0.00
# 476  0.01  -14.0    2.0   10.0    0.32
# 548  0.01   -8.0    2.0   20.0    0.48
# 216  0.01   -8.0    2.0   30.0    0.48
# 359  0.01   -8.0    2.0   40.0    0.48
# 129  0.01   -8.0    2.0   50.0    0.24
# 447  0.01  -10.0    2.0   60.0    0.16
# 28   0.01   -8.0    2.0   70.0    0.08
# 34   0.01   -6.0    2.0   80.0    0.00
# 274  0.01  -10.0    2.0   90.0    0.00
# 25   0.01   -4.0    2.0  100.0    0.00
# ..    ...    ...    ...    ...     ...
# 7    0.01   -8.0    6.0  100.0    0.00
# 371  0.01    0.0    7.0   10.0    0.48
# 174  0.01   -2.0    7.0   20.0    0.48
# 436  0.01   -2.0    7.0   30.0    0.64
# 454  0.01  -12.0    7.0   40.0    0.32
# 211  0.01  -14.0    7.0   50.0    0.40
# 45   0.01   -4.0    7.0   60.0    0.00
# 234  0.01   -6.0    7.0   70.0    0.00
# 26   0.01   -2.0    7.0   80.0    0.00
# 173  0.01  -12.0    7.0   90.0    0.00
# 32   0.01   -4.0    8.0   10.0    0.64
# 74   0.01    2.0    8.0   20.0    0.48
# 415  0.01   -6.0    8.0   30.0    0.64
# 147  0.01  -14.0    8.0   40.0    0.40
# 335  0.01   -6.0    8.0   50.0    0.12
# 449  0.01   -4.0    8.0   60.0    0.00
# 316  0.01  -14.0    8.0   70.0    0.28
# 133  0.01  -14.0    8.0   80.0    0.00
# 6    0.01    0.0    8.0   90.0    0.00
# 101  0.01    2.0    8.0  100.0    0.00
# 132  0.01   -2.0    9.0   10.0    0.32
# 75   0.01    2.0    9.0   20.0    0.32
# 418  0.01   -6.0    9.0   30.0    0.60
# 389  0.01   -8.0    9.0   40.0    0.40
# 9    0.01    0.0    9.0   50.0    0.00
# 427  0.01  -10.0    9.0   60.0    0.16
# 116  0.01    0.0    9.0   70.0    0.00
# 18   0.01   -6.0    9.0   80.0    0.00
# 8    0.01    0.0    9.0   90.0    0.00
# 51   0.01  -10.0    9.0  100.0    0.00
#
# [99 rows x 5 columns]

# %%
import numpy as np
np.mean([ 0.61418699,  0.62443089,  0.62264228,  0.61955285,  0.61479675,
        0.60845528,  0.6004065 ,  0.59402439,  0.58747967,  0.57930894])
# Out:
# 0.60652845399999999

# %%
[ 0.37552846,  0.67117886,  0.70565041,  0.65443089,  0.69378049,
        0.61743902,  0.5499187 ,  0.63044715,  0.66886179,  0.49804878]
# Out:
# [0.37552846,
#  0.67117886,
#  0.70565041,
#  0.65443089,
#  0.69378049,
#  0.61743902,
#  0.5499187,
#  0.63044715,
#  0.66886179,
#  0.49804878]
